# %% [markdown]
# <a href="https://colab.research.google.com/github/pvpkrp/GIT_Practice/blob/new/Untitled29_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Pandas Topic 1:**

# %%
import numpy as np
import pandas as pd

# %%
# !wget "https://drive.google.com/uc?export=download&id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_" -O mckinsey.csv
# Out:
# --2024-08-22 15:23:01--  https://drive.google.com/uc?export=download&id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_
# Resolving drive.google.com (drive.google.com)... 172.217.204.113, 172.217.204.139, 172.217.204.100, ...
# Connecting to drive.google.com (drive.google.com)|172.217.204.113|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_&export=download [following]
# --2024-08-22 15:23:01--  https://drive.usercontent.google.com/download?id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 142.250.98.132, 2607:f8b0:400c:c1a::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|142.250.98.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 83785 (82K) [application/octet-stream]
# Saving to: ‘mckinsey.csv’
#
# ...

# %%
df=pd.read_csv("mckinsey.csv")
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
# !wget https://www.scaler.com/meetings/i/dsml-adv-linear-regression-1/archive - O scaler.csv
# Out:
# --2024-08-22 13:25:47--  https://www.scaler.com/meetings/i/dsml-adv-linear-regression-1/archive
# Resolving www.scaler.com (www.scaler.com)... 3.163.115.121, 3.163.115.98, 3.163.115.17, ...
# Connecting to www.scaler.com (www.scaler.com)|3.163.115.121|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.scaler.com/users/sign_in/ [following]
# --2024-08-22 13:25:48--  https://www.scaler.com/users/sign_in/
# Reusing existing connection to www.scaler.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 65857 (64K) [text/html]
# Saving to: ‘archive.1’
#
# archive.1           100%[===================>]  64.31K   410KB/s    in 0.2s
#
# 2024-08-22 13:25:48 (410 KB/s) - ‘archive.1’ saved [65857/65857]
#
# --2024-08-22 13:25:48--  http://-/
# Resolving - (-)... failed: Name or service not known.
# wget: unable to resolve host address ‘-’
# --2024-08-22 13:25:48--  http://o/
# Resolving o (o)... failed: Name or service not known.
# ...

# %%
df=pd.read_csv("archive.1")
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-318435a74e4f> in <cell line: 1>()
# ----> 1 df=pd.read_csv("archive.1")
#       2 df
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     946     kwds.update(kwds_defaults)
#     947
# ...

# %%
df=pd.read_csv("mckinsey.csv")
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.shape
# Out:
# (1704, 6)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
year=df["year"]
year
# Out:
# 0       1952
# 1       1957
# 2       1962
# 3       1967
# 4       1972
#         ...
# 1699    1987
# 1700    1992
# 1701    1997
# 1702    2002
# 1703    2007
# Name: year, Length: 1704, dtype: int64

# %%
country=df["country"]
country
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
type(country)
# Out:
# pandas.core.series.Series

# %%
# Two types of pandas objects
# 1. Dataframe - 2D, matrix counterpart of pandas
# 2. Series - 1D, 1D array or the vector counterpart in pandas

# %%
# In Pandas, dataframe has mixed data (hetero)
# but every column in homoegenous and that brings certain properties of Numpy (speed) here

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     1704 non-null   object
#  1   year        1704 non-null   int64
#  2   population  1704 non-null   int64
#  3   continent   1704 non-null   object
#  4   life_exp    1704 non-null   float64
#  5   gdp_cap     1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.tail()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1699  Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700  Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %%
df.head(8)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106
# 5  Afghanistan  1977    14880372      Asia    38.438  786.113360
# 6  Afghanistan  1982    12881816      Asia    39.854  978.011439
# 7  Afghanistan  1987    13867957      Asia    40.822  852.395945

# %%
df.tail(7)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1697  Zimbabwe  1977     6642107    Africa    57.674  685.587682
# 1698  Zimbabwe  1982     7636524    Africa    60.363  788.855041
# 1699  Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700  Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %%
# dataframe from scratch
# 1 Row oriented approach
# 2 Column oriented approach

# %%
pd.DataFrame([['Afghanistan',1952, 8425333, 'Asia', 28.801, 779.445314],
              ['Afghanistan',1957, 8425334, 'Asia', 28.801, 820.445314],
             ['Afghanistan',1962, 8425383, 'Asia', 28.801, 930.445314]])
# Out:
#              0     1        2     3       4           5
# 0  Afghanistan  1952  8425333  Asia  28.801  779.445314
# 1  Afghanistan  1957  8425334  Asia  28.801  820.445314
# 2  Afghanistan  1962  8425383  Asia  28.801  930.445314

# %%
pd.DataFrame([['Afghanistan',1952, 8425333, 'Asia', 28.801, 779.445314],
              ['Afghanistan',1957, 8425334, 'Asia', 28.801, 820.445314],
             ['Afghanistan',1962, 8425383, 'Asia', 28.801, 930.445314]],
             columns=['country','year','population','continent','life_exp','gdp_cap'])
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     8425334      Asia    28.801  820.445314
# 2  Afghanistan  1962     8425383      Asia    28.801  930.445314

# %%
pd.DataFrame([['Afghanistan',1952, 8425333, 'Asia', 28.801, 779.445314],
              ['Afghanistan',1957, 8425334, 'Asia', 28.801, 820.445314],
             ['Afghanistan',1962, 8425383, 'Asia', 28.801, 930.445314]],
             columns=['country','year','population','continent','life_exp','gdp_cap'])
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     8425334      Asia    28.801  820.445314
# 2  Afghanistan  1962     8425383      Asia    28.801  930.445314

# %%
pd.DataFrame([['Afghanistan',1962, 102267083, 'Asia', 31.997, 853.100710]],
             columns=['country','year','population','continent','life_exp','gdp_cap'])
# Out:
#        country  year  population continent  life_exp    gdp_cap
# 0  Afghanistan  1962   102267083      Asia    31.997  853.10071

# %%
# column oriented approach - data in the format of columns

# %%
pd.DataFrame({'country':['Afghanistan', 'Afghanistan'], 'year':[1952,1957],
              'population':[842533, 9240934], 'continent':['Asia', 'Asia'],
              'life_exp':[28.801, 30.332], 'gdp_cap':[779.445314, 820.853030]})
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952      842533      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030

# %% [markdown]
# **Agenda**
#
# Rows and column operations
#
# Column operations (no row operation)
#
# Row Operations
#
# Row and Column Ops together

# %% [markdown]
# **Ops of columns**
#
# Accessing the column names - .columns, .keys()
#
# Accesing the column(s) - [[ ]], dot notation (not recommended)
#
# Unique categories - unique(), nunique(), value_counts()
#
# Rename column(s) - .rename(single string or list, axis, inplace)
#
# Delete - drop(single string or list, axis, inplace)
#
# Add a column and Update - just use assignment operation, vectorisation possible

# %%
# checking the name of columns

# %%
df.columns
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
df.keys()
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
df['country']
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
df['population']
# Out:
# 0        8425333
# 1        9240934
# 2       10267083
# 3       11537966
# 4       13079460
#           ...
# 1699     9216418
# 1700    10704340
# 1701    11404948
# 1702    11926563
# 1703    12311143
# Name: population, Length: 1704, dtype: int64

# %%
df.year # this method is personally recommend - Why?
# what if nme of the column was shape - df.shape ismt that a property?
# what if there is a space in the column name "gdp per cap" df.gdp per cap??
# Out:
# 0       1952
# 1       1957
# 2       1962
# 3       1967
# 4       1972
#         ...
# 1699    1987
# 1700    1992
# 1701    1997
# 1702    2002
# 1703    2007
# Name: year, Length: 1704, dtype: int64

# %%
df[['country','population']].head()
# Out:
#        country  population
# 0  Afghanistan     8425333
# 1  Afghanistan     9240934
# 2  Afghanistan    10267083
# 3  Afghanistan    11537966
# 4  Afghanistan    13079460

# %%
df["continent"]
# Out:
# 0         Asia
# 1         Asia
# 2         Asia
# 3         Asia
# 4         Asia
#          ...
# 1699    Africa
# 1700    Africa
# 1701    Africa
# 1702    Africa
# 1703    Africa
# Name: continent, Length: 1704, dtype: object

# %%
df["continent"].unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Americas', 'Oceania'], dtype=object)

# %%
df["country"].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Belgium',
#        'Benin', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Ethiopia',
#        'Finland', 'France', 'Gabon', 'Gambia', 'Germany', 'Ghana',
#        'Greece', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Haiti',
#        'Honduras', 'Hong Kong, China', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kenya', 'Korea, Dem. Rep.',
# ...

# %%
df["country"].nunique()
# Out:
# 142

# %%
df["continent"].value_counts()
# Out:
# continent
# Africa      624
# Asia        396
# Europe      360
# Americas    300
# Oceania      24
# Name: count, dtype: int64

# %%
df['country'].value_counts()
# Out:
# country
# Afghanistan          12
# Pakistan             12
# New Zealand          12
# Nicaragua            12
# Niger                12
#                      ..
# Eritrea              12
# Equatorial Guinea    12
# El Salvador          12
# Egypt                12
# Zimbabwe             12
# Name: count, Length: 142, dtype: int64

# %%
df['country']['Egypt'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-c5ee7c1ea0dd> in <cell line: 1>()
# ----> 1 df['country']['Egypt'].value_counts()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1038
#    1039         elif key_is_scalar:
# -> 1040             return self._get_value(key)
#    1041
#    1042         # Convert generator to list before going through hashable part
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1154
#    1155         # Similar to Index.get_value, but we do not fall back to positional
# -> 1156         loc = self.index.get_loc(label)
#    1157
#    1158         if is_integer(loc):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/range.py in get_loc(self, key)
#     416                 raise KeyError(key) from err
# ...

# %%
df.rename({"population":"Population","country":"Country"}, axis=1, inplace=True)

# %%
df # renaming is not updated in the original dataframe
# Out:
#           Country  year  Population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.drop('continent',axis=1,inplace=True)
df
# Out:
#           Country  year  Population  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333    28.801  779.445314
# 1     Afghanistan  1957     9240934    30.332  820.853030
# 2     Afghanistan  1962    10267083    31.997  853.100710
# 3     Afghanistan  1967    11537966    34.020  836.197138
# 4     Afghanistan  1972    13079460    36.088  739.981106
# ...           ...   ...         ...       ...         ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
# deriving a new column from the old columns
df["gdp"]=df["Population"]*df["gdp_cap"]   # vectorisation + assignment similar to dict

# %%
df
# Out:
#           Country  year  Population  life_exp     gdp_cap           gdp
# 0     Afghanistan  1952     8425333    28.801  779.445314  6.567086e+09
# 1     Afghanistan  1957     9240934    30.332  820.853030  7.585449e+09
# 2     Afghanistan  1962    10267083    31.997  853.100710  8.758856e+09
# 3     Afghanistan  1967    11537966    34.020  836.197138  9.648014e+09
# 4     Afghanistan  1972    13079460    36.088  739.981106  9.678553e+09
# ...           ...   ...         ...       ...         ...           ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306  6.508241e+09
# 1700     Zimbabwe  1992    10704340    60.377  693.420786  7.422612e+09
# 1701     Zimbabwe  1997    11404948    46.809  792.449960  9.037851e+09
# 1702     Zimbabwe  2002    11926563    39.989  672.038623  8.015111e+09
# 1703     Zimbabwe  2007    12311143    43.487  469.709298  5.782658e+09
#
# [1704 rows x 6 columns]

# %%
df["own"]=[i for i in range(1704)]
df
# Out:
#           Country  year  Population  life_exp     gdp_cap           gdp   own
# 0     Afghanistan  1952     8425333    28.801  779.445314  6.567086e+09     0
# 1     Afghanistan  1957     9240934    30.332  820.853030  7.585449e+09     1
# 2     Afghanistan  1962    10267083    31.997  853.100710  8.758856e+09     2
# 3     Afghanistan  1967    11537966    34.020  836.197138  9.648014e+09     3
# 4     Afghanistan  1972    13079460    36.088  739.981106  9.678553e+09     4
# ...           ...   ...         ...       ...         ...           ...   ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306  6.508241e+09  1699
# 1700     Zimbabwe  1992    10704340    60.377  693.420786  7.422612e+09  1700
# 1701     Zimbabwe  1997    11404948    46.809  792.449960  9.037851e+09  1701
# 1702     Zimbabwe  2002    11926563    39.989  672.038623  8.015111e+09  1702
# 1703     Zimbabwe  2007    12311143    43.487  469.709298  5.782658e+09  1703
#
# [1704 rows x 7 columns]

# %%
# Note
# 1. drop, rename - changes were not made to original dataframe
# 2. Adding a new column - changes were reflecting in the original dataframe
# why?
# drop and remname - functions
# adding a column - assignment operation
# ==> Whenever we are using a Pandas function, we need to use inplace=True for permanent changes
# Pandas is following functional prog paradigm = keep data and ops happening on the data sep

# %% [markdown]
# **Pandas Topic 2**

# %% [markdown]
# # #Content

# %% [markdown]
#  - **Working with both rows and columns**
#
# - **More in-built ops in pandas**
#     - sum()
#     - count()
#     - mean()
#
#
# - **Sorting**
#
# - **Concatenation**
#     - pd.concat()
#     - axis for concat
#
#
#
# - **Merge**
#     - Concat v/s Merge
#     - `left_on` and `right_on`
#     - Joins
#
#
# - **Intoduction to IMDB dataset**
#     - Reading two datasets
#
# - **Merging the dataframes**
#     - `unique()` and `nunique()`
#     - `isin()`
#     - Using Left Join for `merge()`
#
# - **Feature Exploration**
#     - Create new features
#
#
# - **Fetching data using pandas**
#     - Quering from dataframe - Masking, Filtering, `&` and `|`
#
#
# - **Apply**

# %% [markdown]
# **Pandas** library
# - We will understand how to work with **both rows and columns**
# - We will look at some **built in pandas operations**, as well as **sorting a dataframe**
# - Along with this, we will learn how to **concatenate and merge two dataframes**
# - We'll also look at some **feature exploration and engineering techniques** for **IMDB dataset** which is our buisness case for today

# %% [markdown]
# # Working with Rows and Columns together

# %% [markdown]
# #### Reading dataset
#
# We will be using our earlier McKinsey dataset for now
#
# Link:https://drive.google.com/file/d/1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_/view?usp=sharing

# %%
# !wget https://drive.google.com/file/d/1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_/view?usp=sharing
# Out:
# --2024-08-26 15:41:01--  https://drive.google.com/file/d/1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_/view?usp=sharing
# Resolving drive.google.com (drive.google.com)... 209.85.145.100, 209.85.145.138, 209.85.145.102, ...
# Connecting to drive.google.com (drive.google.com)|209.85.145.100|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘view?usp=sharing’
#
# view?usp=sharing        [ <=>                ]  87.55K  --.-KB/s    in 0.003s
#
# 2024-08-26 15:41:01 (29.3 MB/s) - ‘view?usp=sharing’ saved [89650]

# %%
# !wget https://drive.google.com/file/d/1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_/view?usp=sharing - O mckinsey.csv
# Out:
# --2024-08-26 15:41:58--  https://drive.google.com/file/d/1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_/view?usp=sharing
# Resolving drive.google.com (drive.google.com)... 209.85.145.101, 209.85.145.102, 209.85.145.113, ...
# Connecting to drive.google.com (drive.google.com)|209.85.145.101|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘view?usp=sharing.1’
#
# view?usp=sharing.1      [ <=>                ]  87.33K  --.-KB/s    in 0.002s
#
# 2024-08-26 15:41:58 (35.9 MB/s) - ‘view?usp=sharing.1’ saved [89429]
#
# --2024-08-26 15:41:58--  http://-/
# Resolving - (-)... failed: Name or service not known.
# wget: unable to resolve host address ‘-’
# --2024-08-26 15:41:58--  http://o/
# Resolving o (o)... failed: Name or service not known.
# wget: unable to resolve host address ‘o’
# --2024-08-26 15:41:58--  http://mckinsey.csv/
# Resolving mckinsey.csv (mckinsey.csv)... failed: Name or service not known.
# ...

# %%
# !wget "https://drive.google.com/file/d/1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_/view?usp=sharing" - O mckinsey.csv
# Out:
# --2024-08-26 15:42:25--  https://drive.google.com/file/d/1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_/view?usp=sharing
# Resolving drive.google.com (drive.google.com)... 209.85.145.101, 209.85.145.102, 209.85.145.113, ...
# Connecting to drive.google.com (drive.google.com)|209.85.145.101|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘view?usp=sharing.2’
#
# view?usp=sharing.2      [ <=>                ]  87.39K  --.-KB/s    in 0.04s
#
# 2024-08-26 15:42:25 (2.07 MB/s) - ‘view?usp=sharing.2’ saved [89484]
#
# --2024-08-26 15:42:25--  http://-/
# Resolving - (-)... failed: Name or service not known.
# wget: unable to resolve host address ‘-’
# --2024-08-26 15:42:25--  http://o/
# Resolving o (o)... failed: Name or service not known.
# wget: unable to resolve host address ‘o’
# --2024-08-26 15:42:25--  http://mckinsey.csv/
# Resolving mckinsey.csv (mckinsey.csv)... failed: Name or service not known.
# ...

# %%
# !wget https://drive.google.com/uc?export=download&id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_ -O mckensey.csv
# Out:
# /bin/bash: line 1: -O: command not found
# --2024-08-26 15:44:51--  https://drive.google.com/uc?export=download
# Resolving drive.google.com (drive.google.com)... 209.85.145.102, 209.85.145.101, 209.85.145.100, ...
# Connecting to drive.google.com (drive.google.com)|209.85.145.102|:443... connected.
# HTTP request sent, awaiting response... 400 Bad Request
# 2024-08-26 15:44:51 ERROR 400: Bad Request.

# %%
# !wget "https://drive.google.com/uc?export=download&id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_" -O mckinsey.csv
# Out:
# --2024-08-26 15:47:32--  https://drive.google.com/uc?export=download&id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_
# Resolving drive.google.com (drive.google.com)... 142.250.125.101, 142.250.125.138, 142.250.125.100, ...
# Connecting to drive.google.com (drive.google.com)|142.250.125.101|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_&export=download [following]
# --2024-08-26 15:47:32--  https://drive.usercontent.google.com/download?id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 74.125.132.132, 2607:f8b0:4001:c00::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|74.125.132.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 83785 (82K) [application/octet-stream]
# Saving to: ‘mckinsey.csv’
#
# ...

# %%
# !wget "https://drive.google.com/uc?export=download&id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_" -O mckinsey.csv
# Out:
# --2024-08-26 15:46:49--  https://drive.google.com/uc?export=download&id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_
# Resolving drive.google.com (drive.google.com)... 209.85.145.101, 209.85.145.102, 209.85.145.100, ...
# Connecting to drive.google.com (drive.google.com)|209.85.145.101|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_&export=download [following]
# --2024-08-26 15:46:49--  https://drive.usercontent.google.com/download?id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 74.125.132.132, 2607:f8b0:4001:c00::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|74.125.132.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 83785 (82K) [application/octet-stream]
# Saving to: ‘mckinsey.csv’
#
# ...

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("mckinsey.csv")
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.tail()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1699  Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700  Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %%
df.head(12)
# Out:
#         country  year  population continent  life_exp     gdp_cap
# 0   Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1   Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2   Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3   Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4   Afghanistan  1972    13079460      Asia    36.088  739.981106
# 5   Afghanistan  1977    14880372      Asia    38.438  786.113360
# 6   Afghanistan  1982    12881816      Asia    39.854  978.011439
# 7   Afghanistan  1987    13867957      Asia    40.822  852.395945
# 8   Afghanistan  1992    16317921      Asia    41.674  649.341395
# 9   Afghanistan  1997    22227415      Asia    41.763  635.341351
# 10  Afghanistan  2002    25268405      Asia    42.129  726.734055
# 11  Afghanistan  2007    31889923      Asia    43.828  974.580338

# %% [markdown]
# #### How can we slice the dataframe into, say, first 4 rows and first 3 columns?
#
# We can use iloc

# %%
df.iloc[1:5,1:4]
# Out:
#    year  population continent
# 1  1957     9240934      Asia
# 2  1962    10267083      Asia
# 3  1967    11537966      Asia
# 4  1972    13079460      Asia

# %%
df.iloc[0:5,0:4]
# Out:
#        country  year  population continent
# 0  Afghanistan  1952     8425333      Asia
# 1  Afghanistan  1957     9240934      Asia
# 2  Afghanistan  1962    10267083      Asia
# 3  Afghanistan  1967    11537966      Asia
# 4  Afghanistan  1972    13079460      Asia
